# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('avocado.csv')

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
df.reset_index(drop=True, inplace = True)
df = df.iloc[:, 1:]
df
# Out:
#              Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1      2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2      2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3      2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4      2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244  2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245  2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246  2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247  2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248  2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
#Date - The date of the observation
#AveragePrice - the average price of a single avocado
#type - conventional or organic
#year - the year
#Region - the city or region of the observation
#Total Volume - Total number of avocados sold
#4046 - Total number of avocados with PLU 4046 sold
#4225 - Total number of avocados with PLU 4225 sold
#4770 - Total number of avocados with PLU 4770 sold

# %%
df.columns
# Out:
# Index(['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year', 'region'],
#       dtype='object')

# %%
df.isna().any()
# Out:
# Date            False
# AveragePrice    False
# Total Volume    False
# 4046            False
# 4225            False
# 4770            False
# Total Bags      False
# Small Bags      False
# Large Bags      False
# XLarge Bags     False
# type            False
# year            False
# region          False
# dtype: bool

# %%
df.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
df.shape
# Out:
# (18249, 13)

# %%
dates = df[df['Date'].duplicated(keep=False)]
dates.sort_values(by='Date', ascending = False).head()
# Out:
#              Date  AveragePrice  Total Volume       4046       4225     4770  \
# 18045  2018-03-25          2.02      13379.77      86.84    5923.16    98.37
# 8814   2018-03-25          1.34    1774776.77   63905.98  908653.71   843.45
# 18153  2018-03-25          1.45     121917.39    1929.39   18391.86   110.05
# 9006   2018-03-25          1.19     450658.34  205952.19   73267.19  4313.11
# 8994   2018-03-25          1.40     524265.69  103573.88  149867.07   998.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 18045     7271.40     6881.80      389.60         0.00       organic  2018
# 8814    801373.63   774634.09    23833.93      2905.61  conventional  2018
# 18153   101486.09    85313.41    16172.68         0.00       organic  2018
# 9006    167125.85   132488.40    31527.74      3109.71  conventional  2018
# 8994    269826.21   155866.80   113666.70       292.71  conventional  2018
#
#                   region
# 18045  RaleighGreensboro
# ...

# %% [markdown]
# Pulling up individual dates, we can see that each region and their purchasing history.

# %%
df['region'].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
df[df['region']=='Plains']
# Out:
#              Date  AveragePrice  Total Volume       4046       4225      4770  \
# 1820   2015-12-27          1.10    1306923.23  571602.60  404837.90  25188.57
# 1821   2015-12-20          1.13    1139861.64  497437.17  341262.17  27253.71
# 1822   2015-12-13          1.02    1472501.13  695419.91  463238.46  17927.73
# 1823   2015-12-06          1.08    1245289.61  579077.46  394656.96  13005.11
# 1824   2015-11-29          1.11    1099646.06  460759.58  364748.79  10648.01
# ...           ...           ...           ...        ...        ...       ...
# 18028  2018-02-04          1.55      62817.64    2624.36   15773.81      4.95
# 18029  2018-01-28          1.64      56920.22    2711.12   14479.56      0.00
# 18030  2018-01-21          1.69      65835.39    3266.67   17088.92      9.85
# 18031  2018-01-14          1.73      63884.71    4071.65   16536.40      2.44
# 18032  2018-01-07          1.72      61712.85    2216.22   18281.23     17.08
#
# ...

# %%
df[df['region']=='Southeast']
# Out:
#              Date  AveragePrice  Total Volume        4046       4225  \
# 2392   2015-12-27          0.98    3024956.05  2045752.24  275823.43
# 2393   2015-12-20          1.12    2206305.07  1449139.49  211595.53
# 2394   2015-12-13          0.96    3042588.20  2127600.06  303892.09
# 2395   2015-12-06          1.13    2205550.58  1520190.48  248205.38
# 2396   2015-11-29          0.97    2615828.04  1797110.09  273706.42
# ...           ...           ...           ...         ...        ...
# 18160  2018-02-04          1.44      96702.50     1589.03   16827.96
# 18161  2018-01-28          1.55     103243.02     1886.12   21288.86
# 18162  2018-01-21          1.48     105688.73     1379.60   16329.87
# 18163  2018-01-14          1.42     106345.74     1053.73   16596.47
# 18164  2018-01-07          1.40     103034.09     1359.47   16209.36
#
#            4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 2392   13994.48   689385.90   425319.18   264039.61        27.11
# ...

# %%
df[df['region']=='Boston']
# Out:
#              Date  AveragePrice  Total Volume     4046       4225      4770  \
# 208    2015-12-27          1.13     450816.39  3886.27  346964.70  13952.56
# 209    2015-12-20          1.07     489802.88  4912.37  390100.99   5887.72
# 210    2015-12-13          1.01     549945.76  4641.02  455362.38    219.40
# 211    2015-12-06          1.02     488679.31  5126.32  407520.22    142.99
# 212    2015-11-29          1.19     350559.81  3609.25  272719.08    105.86
# ...           ...           ...           ...      ...        ...       ...
# 17656  2018-02-04          1.83      28934.01     9.14    2504.27      3.66
# 17657  2018-01-28          1.72      30846.35    14.65    1628.45      0.00
# 17658  2018-01-21          1.82      26704.98    60.87    2647.48      0.00
# 17659  2018-01-14          1.73      29468.36    12.77    2380.23      0.00
# 17660  2018-01-07          1.91      30096.00    14.46    2704.48      0.00
#
# ...

# %% [markdown]
# 'Region' is a group of various regions and cities, and are not uniform for analysis. There's a clear grouping of regions (West, Midsouth, Northeast) and cities (Boston, Las Vegas). It would be more effectively to separate this groups so we can analyze groups.

# %%
import datetime 

df['Date'] = pd.to_datetime(price['Date'])
df.sort_values(by = 'Date', ascending = True, inplace = True)

# %%
#Creating different region bundles
citiesregions = ['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
       'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
       'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
       'Detroit', 'GrandRapids', 'HarrisburgScranton',
       'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
       'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale', 'Nashville', 'NewOrleansMobile', 'NewYork', 'Orlando', 'Philadelphia',
       'PhoenixTucson', 'Pittsburgh', 'Portland',
       'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
       'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina', 'Spokane', 'StLouis', 'Syracuse',
       'Tampa']

regions = ['California', 'GreatLakes',
       'Midsouth', 'Northeast''NorthernNewEngland', 'Plains',
       'SouthCentral', 'Southeast', 'West', 'WestTexNewMexico', 'TotalUS']

citiesdf = df[df['region'].isin(citiesregions)]
regionsdf = df[df['region'].isin(regions)]

# %%
citiesdf.sort_values(by = 'Date', ascending = False, inplace =True)
citiesdf.head()
# Out:
# /Users/Shawn/Documents/UNH_ML_SLF/MLassignments/UNH-Repo/venv/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#             Date  AveragePrice  Total Volume     4046     4225  4770  \
# 18179 2018-03-25          1.71       8092.62  1127.67  2916.23  0.00
# 18191 2018-03-25          1.25       4685.01   168.95    61.01  0.00
# 18165 2018-03-25          1.59       5750.56   266.92  1707.42  2.21
# 18192 2018-03-25          1.42       3061.66   395.14    89.31  0.00
# 18167 2018-03-25          1.72       4790.07   307.23  1845.22  0.00
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18179     4048.72     4022.23       26.49         0.00  organic  2018
# ...

# %%
regionsdf.sort_values(by = 'Date', ascending = False, inplace =True)
regionsdf.head()
# Out:
# /Users/Shawn/Documents/UNH_ML_SLF/MLassignments/UNH-Repo/venv/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#             Date  AveragePrice  Total Volume      4046      4225    4770  \
# 18248 2018-03-25          1.62      17489.58   2894.77   2356.13  224.53
# 18226 2018-03-25          1.73     210067.47  33437.98  47165.54  110.40
# 18228 2018-03-25          1.46     347373.17  25990.60  71213.19   79.01
# 18229 2018-03-25          1.49     301985.61  34200.18  49139.34   85.58
# 18230 2018-03-25          1.64     224798.60  30149.00  38800.64  123.13
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18248    12014.15    11988.14       26.01         0.00  organic  2018
# ...

# %%
import random 
random_region = random.choice(regions)
random_city = random.choice(citiesregions)

regionsdata = regionsdf[regionsdf['region']==random_region]
citiesdata = citiesdf[citiesdf['region']==random_city]

# %%
#Creating lineplot of random region's average avocado pricing
fig = plt.figure()
fig.set_size_inches(12, 8)

sns.lineplot(data=regionsdata, x='Date', y='AveragePrice')
plt.title('{}\'s Avocado Average Prices'.format(random_region), y=1.03, fontsize = 14)

fig.tight_layout()

# %%
filter_year = regionsdata[regionsdata['year']==2016]

fig = plt.figure()
fig.set_size_inches(12, 8)

sns.lineplot(data=filter_year, x='Date', y='AveragePrice')
plt.title('{}\'s Avocado Average Prices for the year 2016'.format(random_region), y=1.03, fontsize = 14)
# Out:
# Text(0.5, 1.03, "GreatLakes's Avocado Average Prices for the year 2016")

# %%
#with region as hue

fig = plt.figure()
fig.set_size_inches(12, 8)

sns.lineplot(data=df, x='Date', y='AveragePrice', hue = 'region')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='AveragePrice'>

# %%
plu = ['Total Volume', '4046', '4225', '4770']
bags = ['Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags']
categories = ['type', 'year', 'region']
price = ['Date', 'AveragePrice']

plu = df[plu]
bags = df[bags]
categories = df[categories]
price = df[price]

# %%
price.reset_index(drop=True, inplace=True)
price
# Out:
#             Date  AveragePrice
# 0     2015-01-04          1.64
# 1     2015-01-04          1.01
# 2     2015-01-04          1.15
# 3     2015-01-04          1.33
# 4     2015-01-04          1.40
# ...          ...           ...
# 18244 2018-03-25          1.32
# 18245 2018-03-25          1.42
# 18246 2018-03-25          1.04
# 18247 2018-03-25          1.02
# 18248 2018-03-25          2.02
#
# [18249 rows x 2 columns]

# %%
plu = ['Total Volume', '4046', '4225', '4770']
bags = ['Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags']
categories = ['type', 'year', 'region']


plu = df[plu]
bags = df[bags]
categories = df[categories]

# %%
import matplotlib.pyplot as plt
from matplotlib import dates
from matplotlib.ticker import MultipleLocator




fig.set_size_inches(12, 45)

plt.plot(df['Date'], df['AveragePrice'])
plt.legend()
ax = plt.gca().get_xaxis()

ax.set_major_locator(MultipleLocator(10))
ax.set_minor_locator(MultipleLocator(0.1))
ax.set_major_formatter(dates.DateFormatter('%Y-%b-%d'))

plt.show()
# Out:
# /var/folders/n4/x3431d_565s25yt88cgb8slc0000gp/T/ipykernel_40500/3356540622.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price['Date'] = pd.to_datetime(price['Date'])
# /Users/Shawn/Documents/UNH_ML_SLF/MLassignments/UNH-Repo/venv/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %%
sns.distplot(a=plu, bins=15, hist=True)
# Out:
# /Users/Shawn/Documents/UNH_ML_SLF/MLassignments/UNH-Repo/venv/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
fig = plt.figure()
j = 1 
fig.set_size_inches(15, 10)

for i in plu.columns:
    ax = fig.add_subplot(2, 2, j)
    sns.distplot(a=plu[i], bins=15, hist=True, ax=ax)
    j += 1

fig.subplots_adjust(hspace=.5)
plt.show()
# Out:
# /Users/Shawn/Documents/UNH_ML_SLF/MLassignments/UNH-Repo/venv/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/Shawn/Documents/UNH_ML_SLF/MLassignments/UNH-Repo/venv/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...
